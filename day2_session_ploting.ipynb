# %%
##  Day2 session for ploting with matplotlib

# %%
# importing library for ploting the data 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="ticks" ,color_codes=True )
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar",data =titanic)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind = "bar",data=titanic)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("iris")
df.head()
sns.set_theme(style="ticks", color_codes=True)
sns.catplot(x="petal_length", y="sepal_length", kind="bar", data= iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-49d46a051212> in <module>
#       4 df.head()
#       5 sns.set_theme(style="ticks", color_codes=True)
# ----> 6 sns.catplot(x="petal_length", y="sepal_length", kind="bar", data= iris)
#       7 plt.show()
#
# NameError: name 'iris' is not defined

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
# plot for counter plot
sns.countplot(x="sex", hue="class", data=titanic)
set_title("counter plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-21b4f54b706d> in <module>
#       5 # plot for counter plot
#       6 sns.countplot(x="sex", hue="class", data=titanic)
# ----> 7 set_title("counter plot")
#       8 plt.show()
#       9
#
# NameError: name 'set_title' is not defined

# %%
## scatter plot
import matplotlib.pyplot as plt
import seaborn as sns 

df = sns.load_dataset("titanic")
sns.set_theme(style="ticks",color_codes=True)
g=sns.FacetGrid(titanic,row="sex", hue="alone")
g=(g.map(plt.scatter, "age","fare").add_legend())
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns
sns.set_theme(style="ticks", color_codes=True)
g= sns.countplot(df, hue= "class", row ="sex")
g= (g.map(plt.scatter, "age","fare",).add_legend())
plt.show()
# Out:
# c:\Users\abc\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1b3c350841b9> in <module>
#       3 df = sns
#       4 sns.set_theme(style="ticks", color_codes=True)
# ----> 5 g= sns.countplot(df, hue= "class", row ="sex")
#       6 g= (g.map(plt.scatter, "age","fare",).add_legend())
#       7 plt.show()
#
# c:\Users\abc\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
# ...
